# %%
# !pip install kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [kaggle]
# ...

# %%
import os

# Set up Kaggle credentials
os.environ['KAGGLE_USERNAME'] = 'menglh20'
os.environ['KAGGLE_KEY'] = 'KGAT_afb4e70e230190e963ff4a9d9efc2e22'

# %%
# !kaggle datasets download -d sunnyagarwal427444/food-ingredient-dataset-51 --unzip -p ./data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sunnyagarwal427444/food-ingredient-dataset-51
# License(s): MIT
# ...
# 100%|██████████████████████████████████████| 1.83G/1.83G [01:50<00:00, 17.8MB/s]

# %%
# Verify downloaded files
for f in os.listdir('./data'):
    print(f)
# Out:
# huggingface
